# %%
from premise import NewDatabase
import bw2data as bd

# %%
ei_version = "3.10"
bw_project = f"internalizer_ei_{ei_version}"

# %%
bd.projects.set_current(bw_project)

# %%
scen = [
    {
        "model": "remind",
        "pathway": "SSP2-PkBudg650",
        "year": 2050
    }
]
ei_label = "ecoinvent-{}-cutoff".format(ei_version)
ndb = NewDatabase(
    scenarios=scen,
    source_db=ei_label,
    source_version=ei_version,
    biosphere_name="ecoinvent-{}-biosphere".format(ei_version)
)
# Out:
# Reading unencrypted IAM output files.
# premise v.(2, 3, 0, 'dev1')
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your Brightway project:                                   |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_source_db_uncertainty=True), keep_imports_uncertainty=True)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
# - Extracting source database
# - Extracting inventories
# - Fetching IAM data
# Reading /home/davidba/.conda/envs/internalizer/lib/python3.11/site-packages/premise/data/iam_output_files/remind_SSP2-PkBudg650.csv as csv file
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/internalizer/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'variable'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 9
#       1 scen = [
#       2     {
#       3         "model": "remind",
#    (...)      6     }
#       7 ]
#       8 ei_label = "ecoinvent-{}-cutoff".format(ei_version)
# ----> 9 ndb = NewDatabase(
#      10     scenarios=scen,
#      11     source_db=ei_label,
#      12     source_version=ei_version,
#      13     biosphere_name="ecoinvent-{}-biosphere".format(ei_version)
#      14 )
#
# File ~/.conda/envs/internalizer/lib/python3.11/site-packages/premise/new_database.py:646, in NewDatabase.__init__(self, scenarios, source_version, source_type, key, source_db, source_file_path, additional_inventories, system_model, system_args, use_cached_inventories, use_cached_database, external_scenarios, quiet, keep_imports_uncertainty, keep_source_db_uncertainty, gains_scenario, use_absolute_efficiency, biosphere_name)
#     644 print("- Fetching IAM data")
#     645 for scenario in self.scenarios:
# --> 646     _fetch_iam_data(scenario)
#     648 print("Done!")
#
# File ~/.conda/envs/internalizer/lib/python3.11/site-packages/premise/new_database.py:598, in NewDatabase.__init__.<locals>._fetch_iam_data(scenario)
#     597 def _fetch_iam_data(scenario):
# --> 598     data = IAMDataCollection(
#     599         model=scenario["model"],
#     600         pathway=scenario["pathway"],
#     601         year=scenario["year"],
#     602         external_scenarios=scenario.get("external scenarios"),
#     603         filepath_iam_files=scenario["filepath"],
#     604         key=key,
#     605         system_model=self.system_model,
#     606         system_model_args=self.system_model_args,
#     607         gains_scenario=self.gains_scenario,
#     608         use_absolute_efficiency=self.use_absolute_efficiency,
#     609     )
#     610     scenario["iam data"] = data
#     612     if "external scenarios" in scenario:
#
# File ~/.conda/envs/internalizer/lib/python3.11/site-packages/premise/data_collection.py:480, in IAMDataCollection.__init__(self, model, pathway, year, filepath_iam_files, key, external_scenarios, system_model, system_model_args, gains_scenario, use_absolute_efficiency)
#     474 new_vars = flatten(new_vars)
#     476 # if "liquid fossil fuels" is in the list of fuel variables
#     477 # we add the split of gasoline, diesel, LPG and kerosene
#     478 # to `data`, because it means it's not already in the IAM file.
# --> 480 data = self.__get_iam_data(
#     481     key=key,
#     482     filedir=filepath_iam_files,
#     483     variables=new_vars,
#     484     split_fossil_liquid_fuels=(
#     485         {
#     486             k: v
#     487             for k, v in fuel_prod_vars.items()
#     488             if k in ["gasoline", "diesel", "kerosene", "liquid fossil fuels"]
#     489         }
#     490         if "liquid fossil fuels" in fuel_prod_vars
#     491         else None
#     492     ),
#     493 )
#     495 self.data = data
#     497 self.regions = data.region.values.tolist()
#
# File ~/.conda/envs/internalizer/lib/python3.11/site-packages/premise/data_collection.py:1187, in IAMDataCollection.__get_iam_data(self, key, filedir, variables, split_fossil_liquid_fuels)
#    1184 variable_liquid_fuel = split_fossil_liquid_fuels["liquid fossil fuels"]
#    1186 for fuel_var, iam_var in split_fossil_liquid_fuels.items():
# -> 1187     if iam_var not in dataframe["variable"].unique():
#    1188         new_fuel_df = copy.deepcopy(
#    1189             dataframe.loc[dataframe["variable"] == variable_liquid_fuel]
#    1190         )
#    1191         fuel_share = df[fuel_var].reindex(new_fuel_df["region"])
#
# File ~/.conda/envs/internalizer/lib/python3.11/site-packages/pandas/core/frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File ~/.conda/envs/internalizer/lib/python3.11/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'variable'
