# %%
import pandas as pd

# %%
pe2se = pd.read_csv("./mappings/pe2se.csv", sep=";")
pe2se
# Out:
#           REMIND name                                       dataset name  \
# 0     pegas.seel.ngcc  electricity production, natural gas, combined ...
# 1    pegas.seel.ngccc  electricity production, at natural gas-fired c...
# 2      pegas.seel.ngt  electricity production, natural gas, conventio...
# 3   pegas.seel.gaschp  heat and power co-generation, natural gas, com...
# 4   pegas.seel.gaschp  heat and power co-generation, natural gas, com...
# ..                ...                                                ...
# 74     pesol.seel.csp  electricity production, solar tower power plan...
# 75     pesol.seel.csp  electricity production, solar thermal paraboli...
# 76   pesol.sehe.solhe  operation, solar collector system, Cu flat pla...
# 77     peur.seel.tnrs  electricity production, nuclear, pressure wate...
# 78     peur.seel.fnrs  electricity production, nuclear, pressure wate...
#
#                             dataset reference product   dataset unit     share
# 0                           electricity, high voltage  kilowatt hour       1.0
# 1                           electricity, high voltage  kilowatt hour       1.0
# 2                           electricity, high voltage  kilowatt hour       1.0
# 3                           electricity, high voltage  kilowatt hour  regional
# 4           heat, district or industrial, natural gas      megajoule  regional
# ..                                                ...            ...       ...
# 74                          electricity, high voltage  kilowatt hour       0.5
# 75                          electricity, high voltage  kilowatt hour       0.5
# 76  heat, central or small-scale, other than natur...      megajoule       1.0
# 77                          electricity, high voltage  kilowatt hour       1.0
# 78                          electricity, high voltage  kilowatt hour       1.0
#
# [79 rows x 5 columns]

# %%
pe2se["all_te"] = pe2se["REMIND name"].apply(lambda x: x.split(".")[-1])

# %%
pe2se[["all_te", "dataset name", "dataset reference product", "dataset unit", "share"]].to_csv("./mappings/pe2se.csv", sep=";", index=False)
