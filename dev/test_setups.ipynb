# %%
from internalizer.calculation_setup import prepare_setup

# %%
mappings = ["./mappings/test_PE.csv", "./mappings/test_SE.csv"]

prepare_setup(mappings, remove_layers="other")
# Out:
# {'test_PE': {'mapping':    REMIND index                                       dataset name  \
#   0        pecoal  hard coal mine operation and hard coal prepara...
#   1        pecoal                             lignite mine operation
#   2         pegas              petroleum and gas production, onshore
#   3         pegas             petroleum and gas production, offshore
#   4         peoil              petroleum and gas production, onshore
#   ..          ...                                                ...
#   91        pegas             petroleum and gas production, offshore
#   92        peoil              petroleum and gas production, onshore
#   93        peoil             petroleum and gas production, offshore
#   94         peur                uranium mine operation, underground
#   95         peur                  uranium mine operation, open cast
#
#        dataset reference product dataset unit  share region
# ...
